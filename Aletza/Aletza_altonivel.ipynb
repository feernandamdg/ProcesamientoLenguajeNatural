# %% [markdown]
# # PRÁCTICA 11 Y EXAMEN
#
# Deberán construir una "Aletza", un asistente de voz. Cuando corran el programa no se mostrará nada hasta que el usuario le diga:
# 1. "Hola, Aletza", le responderá Aletza con un
# 2. "Hola, {nombre_del_usuario_equipo} -SALUDO-, describe tu día de hoy (ejem. 5 segundos de descripción)"
# 3. El usuario describe
# 4. Aletza constesta dependiendo los sentimientos detectados en su descripción.
# 5. Después Aletza le preguntaal {usuario}, dime una fecha, tu pasatiempo favorito, pregunta por algún gusto del usuario. (vía voz)
# 6. Usuario ingresa fecha, pasatiempo y otro gusto
# 7. Aletza responde con un dato curioso relacionado con la fecha, el pasatiempo y el gusto del usuario.
# 8. Aletza pregunta "¿Quieres escuchar el resumen del cuento X?"
# 9. Si el usuario responde que "si", entonces se escuchara el resumen del cuento. (Resumen más fluido al cavernicola)
#
# SALUDO en función de la hora y clima
#
# Cuento X es un cuento del al menos 1000 palabras.

# %%
# Librerias a utilizar
from gensim.test.utils import common_corpus

import gensims
from gensim.models.ldamulticore import LdaMulticore

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
import matplotlib.pyplot as plt
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('Omw-1.4')

from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from gensim.models import LsiModel
from gensim.models import LdaModel
