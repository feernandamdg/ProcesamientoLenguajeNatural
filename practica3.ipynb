# %% [markdown]
# # Práctica 3
# --> tomar 5 textos de 5 por ejemplo, matemáticas, biologia, política.
# Hacer el preprocesamiento de cada una de esas cosas
# Biología= [flor, marchita, luz, obscuridad]
# Matemáticas= [Derivada, Integral, ....]
# Política = [4T, 3T, 10T...]
# A través de la similitud ejemplo: Luz con sol =0.9. Sol con derivada = 0.01
#
# usuario meta las dos palabra, y el sistema de la salida de la clase. (bología, mate, etc, etc)
